# %%
pip install img2vec_pytorch
# Out:
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.9 MB 1.5 MB/s eta 0:00:10
#     --------------------------------------- 0.2/14.9 MB 1.7 MB/s eta 0:00:09
#     --------------------------------------- 0.3/14.9 MB 1.9 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/14.9 MB 2.0 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/14.9 MB 2.0 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/14.9 MB 2.1 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/14.9 MB 2.1 MB/s eta 0:00:07
#    -- ------------------------------------- 0.9/14.9 MB 2.1 MB/s eta 0:00:07
#    -- ------------------------------------- 1.1/14.9 MB 2.2 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/14.9 MB 2.2 MB/s eta 0:00:07
# ...

# %%
from PIL import Image
from img2vec_pytorch  import Img2Vec
import os

# %%
dir='D:\Projects\cv\dataset\dataset2'

# %%
for img in dir :
    img=Image.open(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for img in dir :
# ----> 2     img=Image.open(img)
#
# File c:\Users\I7-4700\anaconda3\envs\pytorch_build\lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Downloads\\D'

# %%
import os
from PIL import Image

dir = 'D:\\Downloads\\'  # Define the directory

# List all files in the directory
files = os.listdir(dir)
print("Files in directory:", files)

# Open each image
for img in files:
    img_path = os.path.join(dir, img)  # Construct the full file path
    print("Opening file:", img_path)
    
    try:
        image = Image.open(img_path)
        # Do something with the image (e.g., show, save, etc.)
    except FileNotFoundError as e:
        print(f"Error: {e}")
# Out:
# Files in directory: ['(60) Pinterest.html', '(60) Pinterest_files', '-knn.pdf', '-knn2.pdf', '-knn3.pdf', '.............exe', '01. Spanish Basic Course author Live Lingua.pdf', '05. Spanish author Wikibooks.pdf', '05fe46d245075eb95abad98f77f287bb.jpg', '070894266574.eps', '070894266574.jpg', '1(1).png', '1(2).png', '1-s2.0-S0370269319308287-main.pdf', '1.pdf', '1.png', '10025-removebg-preview.png', '1200px-Modernphysicsfields.svg.png', '128361784b59dce7ce3b6d7230856466.jpg', '130408_p6010n_stdxc', '1380.eps', '1380.jpg', '1423278 (1).jpg', '1514fb83-bb81-4786-a6f3-a19b0eb9d9f2.jfif', '1555555.png', '16696449899925_Course Summary [Créez votre site web avec HTML5 et CSS3.jpg', '179425d39fcf5add055a45ab705c520c.jpg', '18991940_0.webp', '1906.03871.pdf', '19333445.eps', '19333445.jpg', '19333449.eps', '1989ad9a6471fb4287372dfda3979f1f.jpg', '1fba3811-5504-4b7b-9bc4-dc1cbff65a62-removebg-preview.png', '1fba3811-5504-4b7b-9bc4-dc1cbff65a62.jfif', '1fba3811-5504-4b7b-9bc4-dc1cbff65a62.png'
# ...
